# %%
"""
This example demonstrates the workflow to download a publicly available 
TensorFlow model and convert it to Core ML format using the tfcoreml converter.

We use an open source implementation of DeepSpeech model (https://arxiv.org/abs/1412.5567) 
provided by Mozilla: https://github.com/mozilla/DeepSpeech.
"""

# %%
import tfcoreml
import numpy as np
import tensorflow as tf
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0710 16:59:39.237015 4739939648 __init__.py:71] TensorFlow version 1.14.0 detected. Last version known to be fully compatible is 1.13.1 .

# %%
# Download TensorFlow implementation of DeepSpeech model from https://github.com/mozilla/DeepSpeech
# wget https://github.com/mozilla/DeepSpeech/releases/download/v0.4.1/deepspeech-0.4.1-models.tar.gz
# tar xvfz deepspeech-0.4.1-models.tar.gz

# %%
tfmodel_path = './models/output_graph.pb'  # path to the downloaded model
mlmodel_path = './deep_speech.mlmodel'  # path to save converted Core ML model

# convert model and save to the local directory
model = tfcoreml.convert(
    tf_model_path=tfmodel_path, 
    mlmodel_path=mlmodel_path,
        input_name_shape_dict={
        'input_node': [1, 16, 19, 26],
        'input_lengths': [1],
        'previous_state_h': [1, 2048],
        'previous_state_c': [1, 2048]
    },
    output_feature_names=['logits'],
    use_coreml_3=True
)

# Optionally, we can print and inspect converted Core ML model
# from coremltools.models.neural_network.printer import print_network_spec_coding_style
# print_network_spec_coding_style(model.get_spec())
# Out:
# W0710 16:59:39.820260 4739939648 deprecation_wrapper.py:119] From /Volumes/data/work/coreml/coremltools/coremltools/converters/nnssa/frontend/tensorflow/graphdef_to_ssa.py:21: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0710 16:59:39.821039 4739939648 deprecation_wrapper.py:119] From /Volumes/data/work/coreml/coremltools/coremltools/converters/nnssa/frontend/tensorflow/graphdef_to_ssa.py:22: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
# 0 assert nodes deleted
# W0710 16:59:41.819582 4739939648 deprecation_wrapper.py:119] From /Volumes/data/work/coreml/coremltools/coremltools/converters/nnssa/frontend/tensorflow/graph_pass/constant_propagation.py:62: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# ['b1/read:0', 'lstm_fused_cell/range_1/delta:0', 'Minimum_3/y:0', 'b3:0', 'lstm_fused_cell/ExpandDims_1/dim:0', 'lstm_fused_cell/range/delta:0', 'lstm_fused_cell/transpose/perm:0', 'h6:0', 'lstm_fused_cell/zeros:0', 'lstm_fused_cell/range_1/start:0', 'zeros:0', 'lstm_fused_cell/zeros/shape_as_tensor:0', 'lstm_fused_cell/zeros/Const:0', 'h1:0', 'lstm_fused_cell/ExpandDims/dim:0', 'transpose/perm:0', 'h6/read:0', 'h5:0', 'lstm_fused_cell/range/start:0', 'b6/read:0', 'Reshape_1/shape:0', 'lstm_fused_cell/ExpandDims_2/dim:0', 'lstm_fused_cell/range_1:0', 'h3/read:0', 'b2:0', 'lstm_fused_cell/SequenceMask/ExpandDims/dim:0', 'lstm_fused_cell/SequenceMask/Const_2:0', 'b2/read:0', 'lstm_fused_cell/concat/axis:0', 'Reshape_2/shape:0', 'h5/read:0', 'lstm_fused_cell/kernel/read:0', 'lstm_fused_cell/bias/read:0', 'lstm_fused_cell/Tile/multiples:0', 'b5:0', 'b6:0', 'lstm_fused_cell/range_1/limit:0', 'b3/read:0', 'zeros/Const:0', 'Reshape/shape:0', 'b5/read:0', 'h1/read:0', 'lstm_fused_cell/bias:0', 'h3:0', 'lstm_fused_cell/range:0', 'Minimum/y:0', 'lstm_fused_cell/Const:0', 'b1:0', 'h2:0', 'lstm_fused_cell/SequenceMask/Const:0', 'lstm_fused_cell/SequenceMask/Const_1:0', 'h2/read:0', 'raw_logits/shape:0', 'zeros/shape_as_tensor:0', 'lstm_fused_cell/concat_1/axis:0', 'lstm_fused_cell/SequenceMask/Range:0', 'lstm_fused_cell/kernel:0', 'Minimum_2/y:0', 'lstm_fused_cell/range/limit:0', 'Minimum_1/y:0']
# 25 nodes deleted
# 0 nodes deleted
# 0 nodes deleted
# 2 identity nodes deleted
# 5 disconnected nodes deleted
# [SSAConverter] Converting function main ...
# [SSAConverter] [1/76] Converting op input_node: Placeholder
# [SSAConverter] [2/76] Converting op input_lengths: Placeholder
# [SSAConverter] [3/76] Converting op previous_state_c/read: get_global
# [SSAConverter] [4/76] Converting op previous_state_h/read: get_global
# [SSAConverter] [5/76] Converting op transpose/perm: Const
# [SSAConverter] [6/76] Converting op Reshape/shape: Const
# [SSAConverter] [7/76] Converting op b1/read: Const
# [SSAConverter] [8/76] Converting op Minimum/y: Const
# [SSAConverter] [9/76] Converting op b2/read: Const
# [SSAConverter] [10/76] Converting op Minimum_1/y: Const
# [SSAConverter] [11/76] Converting op b3/read: Const
# [SSAConverter] [12/76] Converting op Minimum_2/y: Const
# [SSAConverter] [13/76] Converting op Reshape_1/shape: Const
# [SSAConverter] [14/76] Converting op lstm_fused_cell/kernel/read: Const
# [SSAConverter] [15/76] Converting op lstm_fused_cell/bias/read: Const
# [SSAConverter] [16/76] Converting op lstm_fused_cell/SequenceMask/Range: Const
# [SSAConverter] [17/76] Converting op lstm_fused_cell/SequenceMask/ExpandDims/dim: Const
# [SSAConverter] [18/76] Converting op lstm_fused_cell/transpose/perm: Const
# [SSAConverter] [19/76] Converting op lstm_fused_cell/ExpandDims/dim: Const
# [SSAConverter] [20/76] Converting op lstm_fused_cell/Tile/multiples: Const
# [SSAConverter] [21/76] Converting op lstm_fused_cell/ExpandDims_1/dim: Const
# [SSAConverter] [22/76] Converting op lstm_fused_cell/concat/axis: Const
# [SSAConverter] [23/76] Converting op lstm_fused_cell/ExpandDims_2/dim: Const
# [SSAConverter] [24/76] Converting op lstm_fused_cell/concat_1/axis: Const
# [SSAConverter] [25/76] Converting op lstm_fused_cell/range: Const
# [SSAConverter] [26/76] Converting op lstm_fused_cell/range_1: Const
# [SSAConverter] [27/76] Converting op Reshape_2/shape: Const
# [SSAConverter] [28/76] Converting op b5/read: Const
# [SSAConverter] [29/76] Converting op Minimum_3/y: Const
# [SSAConverter] [30/76] Converting op b6/read: Const
# [SSAConverter] [31/76] Converting op raw_logits/shape: Const
# [SSAConverter] [32/76] Converting op transpose: Transpose
# [SSAConverter] [33/76] Converting op lstm_fused_cell/SequenceMask/ExpandDims: ExpandDims
# [SSAConverter] [34/76] Converting op lstm_fused_cell/ExpandDims_1: ExpandDims
# [SSAConverter] [35/76] Converting op lstm_fused_cell/ExpandDims_2: ExpandDims
# [SSAConverter] [36/76] Converting op lstm_fused_cell/stack: Pack
# [SSAConverter] [37/76] Converting op lstm_fused_cell/stack_1: Pack
# [SSAConverter] [38/76] Converting op Reshape: Reshape
# [SSAConverter] [39/76] Converting op lstm_fused_cell/SequenceMask/Cast: Cast
# [SSAConverter] [40/76] Converting op MatMul: MatMul
# [SSAConverter] [41/76] Converting op lstm_fused_cell/SequenceMask/Less: Less
# [SSAConverter] [42/76] Converting op Add: Add
# [SSAConverter] [43/76] Converting op lstm_fused_cell/SequenceMask/Cast_1: Cast
# [SSAConverter] [44/76] Converting op Relu: Relu
# [SSAConverter] [45/76] Converting op lstm_fused_cell/transpose: Transpose
# [SSAConverter] [46/76] Converting op Minimum: Minimum
# [SSAConverter] [47/76] Converting op lstm_fused_cell/ExpandDims: ExpandDims
# [SSAConverter] [48/76] Converting op MatMul_1: MatMul
# [SSAConverter] [49/76] Converting op lstm_fused_cell/Tile: Tile
# [SSAConverter] [50/76] Converting op Add_1: Add
# [SSAConverter] [51/76] Converting op Relu_1: Relu
# [SSAConverter] [52/76] Converting op Minimum_1: Minimum
# [SSAConverter] [53/76] Converting op MatMul_2: MatMul
# [SSAConverter] [54/76] Converting op Add_2: Add
# [SSAConverter] [55/76] Converting op Relu_2: Relu
# [SSAConverter] [56/76] Converting op Minimum_2: Minimum
# [SSAConverter] [57/76] Converting op Reshape_1: Reshape
# [SSAConverter] [58/76] Converting op lstm_fused_cell/BlockLSTM/LSTMBlock: LSTMBlock
# [SSAConverter] [59/76] Converting op lstm_fused_cell/BlockLSTM/get_tuple: get_tuple
# [SSAConverter] [60/76] Converting op lstm_fused_cell/BlockLSTM/get_tuple_0: get_tuple
# [SSAConverter] [61/76] Converting op lstm_fused_cell/mul: Mul
# [SSAConverter] [62/76] Converting op lstm_fused_cell/concat: ConcatV2
# [SSAConverter] [63/76] Converting op lstm_fused_cell/concat_1: ConcatV2
# [SSAConverter] [64/76] Converting op Reshape_2: Reshape
# [SSAConverter] [65/76] Converting op lstm_fused_cell/GatherNd: GatherNd
# [SSAConverter] [66/76] Converting op lstm_fused_cell/GatherNd_1: GatherNd
# [SSAConverter] [67/76] Converting op MatMul_3: MatMul
# [SSAConverter] [68/76] Converting op Assign_2: set_global
# [SSAConverter] [69/76] Converting op Assign_3: set_global
# [SSAConverter] [70/76] Converting op Add_3: Add
# [SSAConverter] [71/76] Converting op Relu_3: Relu
# [SSAConverter] [72/76] Converting op Minimum_3: Minimum
# [SSAConverter] [73/76] Converting op MatMul_4: MatMul
# [SSAConverter] [74/76] Converting op Add_4: Add
# [SSAConverter] [75/76] Converting op raw_logits: Reshape
# [SSAConverter] [76/76] Converting op logits: Softmax
# [MLModel Pass] 15 disconnected constants are removed from graph.

# %%
# Generate some random data as inputs
input_node = np.random.rand(1, 16, 19, 26) * 10.
input_lengths = np.array([16], dtype=np.int32)
previous_state_c = np.random.rand(1, 2048)
previous_state_h = np.random.rand(1, 2048)

# %%
# Run predictions
out = model.predict({
    'input_node': input_node,
    'input_lengths': input_lengths,
    'previous_state_h': previous_state_h,
    'previous_state_c': previous_state_c
})['logits']

output = np.array(out)
print(output)
# Out:
# [[[9.53124891e-06 9.94660786e-06 4.83189033e-05 3.77420868e-08
#    2.37063468e-05 2.40536410e-05 3.72992645e-07 1.31326542e-05
#    1.61471871e-05 4.65087978e-05 1.07197133e-11 4.61233007e-08
#    5.86524107e-10 2.02576248e-05 3.76890880e-12 1.70961630e-06
#    9.99857843e-01]]
#
#  [[1.49995617e-06 6.91985088e-06 2.37508672e-07 1.47010146e-08
#    1.10381188e-06 1.72109376e-05 1.18130309e-07 3.27521690e-07
#    2.51454503e-06 3.36987287e-05 4.95374408e-10 4.65968313e-08
#    2.54002657e-07 3.42369162e-07 3.59531964e-06 4.15392014e-06
#    1.27909914e-08 2.49596134e-12 4.19635938e-07 1.53416238e-06
#    1.66168945e-06 3.58686066e-06 1.43800909e-08 5.61674199e-07
#    8.63837113e-10 7.56097415e-06 5.54243543e-12 7.24030031e-07
#    9.99911845e-01]]
#
#  [[2.00334625e-06 4.41938892e-06 2.18598018e-07 8.30265989e-09
#    6.32795604e-07 7.81230210e-06 1.07296401e-07 2.26109719e-07
#    2.89093532e-06 1.11077252e-05 5.82896009e-10 1.01849267e-07
#    3.64323625e-07 5.65525852e-07 2.48572383e-06 1.73904084e-06
#    3.25324190e-09 1.11955367e-11 3.12060564e-07 7.09618575e-07
#    1.60950674e-06 4.66249276e-06 1.47699302e-08 2.32021739e-06
#    2.29606023e-09 9.30780698e-06 6.51585383e-12 1.36719237e-07
#    9.99946237e-01]]
#
#  [[2.72147372e-05 4.79763185e-05 2.61992136e-06 2.54423441e-07
#    4.53913844e-06 4.73280161e-05 5.32244485e-07 2.70752162e-06
#    1.38926926e-05 5.62869282e-05 2.04759960e-08 7.30502279e-07
#    1.93152528e-06 7.73256579e-06 1.31117313e-05 1.43033240e-05
#    1.34355119e-07 5.47292822e-10 3.37161896e-06 4.21796176e-06
#    5.13198438e-06 4.63571378e-05 1.15787557e-07 1.86082852e-05
#    6.98984515e-09 8.13747538e-05 6.71995931e-11 6.92632227e-07
#    9.99598861e-01]]
#
#  [[9.04491480e-06 1.04275503e-04 3.75252375e-06 2.37449581e-06
#    2.76958435e-05 9.81261619e-05 1.86541149e-06 4.24742648e-05
#    1.50774329e-04 6.72430615e-05 1.25854470e-07 2.81713847e-06
#    5.78221261e-06 4.11393703e-05 9.68704626e-05 9.51456022e-05
#    1.44105491e-06 9.19981813e-10 1.81654195e-05 2.96675735e-05
#    2.29684574e-05 2.40026420e-04 1.01850139e-06 3.63136060e-05
#    4.49509514e-08 1.32190980e-04 2.66699018e-09 6.12313124e-06
#    9.98762488e-01]]]

# %%
# Optionally we can verify the predictions are consistant with TensorFlow's output
from tensorflow.contrib.rnn import *

with open(tfmodel_path, 'rb') as f:
    serialized = f.read()
original_gdef = tf.compat.v1.GraphDef()
original_gdef.ParseFromString(serialized)

tf.import_graph_def(original_gdef, name="")

with tf.Session() as sess:
    g = sess.graph
    out = g.get_tensor_by_name('Softmax:0')
    in1 = g.get_tensor_by_name('input_node:0')
    in2 = g.get_tensor_by_name('input_lengths:0')
    in3 = g.get_tensor_by_name('previous_state_c:0')
    in4 = g.get_tensor_by_name('previous_state_h:0')

    tf_out = sess.run(out, feed_dict={
        in1: input_node, in2: input_lengths, in3: previous_state_c, in4: previous_state_h,
    })

tf_output = np.array(tf_out)

# %%
assert output.shape == tf_output.shape
np.testing.assert_almost_equal(output.flatten(), tf_output.flatten(), decimal=4)
